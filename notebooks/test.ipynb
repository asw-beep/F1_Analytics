# %%
import pandas as pd

df = pd.read_csv("../data/processed/featured_dataset.csv")

print(df[[
    "driver_name",
    "circuitId",
    "finish_position",
    "driver_circuit_avg_finish"
]].head(20))
# Out:
#        driver_name  circuitId  finish_position  driver_circuit_avg_finish
# 0   Lewis Hamilton          1                3                        NaN
# 1   Lewis Hamilton          1                1                   3.000000
# 2   Lewis Hamilton          1                6                   2.000000
# 3   Lewis Hamilton          1                2                   3.333333
# 4   Lewis Hamilton          1                3                   3.000000
# 5   Lewis Hamilton          1                5                   3.000000
# 6   Lewis Hamilton          1                1                   3.333333
# 7   Lewis Hamilton          1                2                   3.000000
# 8   Lewis Hamilton          1                2                   2.875000
# 9   Lewis Hamilton          1                2                   2.777778
# 10  Lewis Hamilton          1                2                   2.700000
# 11  Lewis Hamilton          1                4                   2.636364
# ...
